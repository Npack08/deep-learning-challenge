# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
new_application_df = application_df.drop(['EIN', 'NAME'], axis=1)
new_application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_columns=["APPLICATION_TYPE","AFFILIATION","CLASSIFICATION", "USE_CASE","ORGANIZATION","STATUS","INCOME_AMT","SPECIAL_CONSIDERATIONS","ASK_AMT","IS_SUCCESSFUL"]
unique_values = new_application_df[application_columns]
unique_values.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = new_application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_type_counts[application_type_counts < 700].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_value_counts = new_application_df['CLASSIFICATION'].value_counts()
classification_value_counts.head()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `classification_types_to_replace`
classification_types_to_replace = list(classification_value_counts[classification_value_counts < 400].index)

# Replace in dataframe
for cls in classification_types_to_replace:
    application_df['CLASSIFICATION_TYPE'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2235
# C3000     1918
# C2100     1883
# C1370        1
# C1236        1
# C2190        1
# C4200        1
# C5200        1
# C1248        1
# C2600        1
# C1580        1
# C6100        1
# C1820        1
# C1900        1
# C2570        1
# C1570        1
# C3700        1
# C2500        1
# C1283        1
# C2380        1
# C1732        1
# C1728        1
# C2170        1
# C4120        1
# C8210        1
# C4500        1
# C1245        1
# C2561        1
# C2150        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_df = pd.get_dummies(new_application_df)
numeric_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
y=numeric_df["IS_SUCCESSFUL"]
x = numeric_df.drop(["IS_SUCCESSFUL"],axis=1)
# Split the preprocessed data into a training and testing dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
x_scaler = scaler.fit(x_train)

# Scale the data
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled = x_scaler.transform(x_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(x_train_scaled[0])
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(hidden_nodes_layer1, input_dim= input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 10)                1170
#
#  dense_19 (Dense)            (None, 20)                220
#
#  dense_20 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 1,411
# Trainable params: 1,411
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Attempt 1

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(x_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5999 - accuracy: 0.6924
# Epoch 2/100
# 858/858 [==============================] - 1s 966us/step - loss: 0.5582 - accuracy: 0.7293
# Epoch 3/100
# 858/858 [==============================] - 1s 930us/step - loss: 0.5522 - accuracy: 0.7325
# Epoch 4/100
# 858/858 [==============================] - 1s 961us/step - loss: 0.5501 - accuracy: 0.7321
# Epoch 5/100
# 858/858 [==============================] - 1s 975us/step - loss: 0.5482 - accuracy: 0.7327
# Epoch 6/100
# 858/858 [==============================] - 1s 998us/step - loss: 0.5473 - accuracy: 0.7336
# Epoch 7/100
# 858/858 [==============================] - 1s 947us/step - loss: 0.5459 - accuracy: 0.7342
# Epoch 8/100
# 858/858 [==============================] - 1s 992us/step - loss: 0.5454 - accuracy: 0.7349
# Epoch 9/100
# 858/858 [==============================] - 1s 985us/step - loss: 0.5446 - accuracy: 0.7348
# Epoch 10/100
# 858/858 [==============================] - 1s 951us/step - loss: 0.5441 - accuracy: 0.7348
# Epoch 11/100
# 858/858 [==============================] - 1s 964us/step - loss: 0.5438 - accuracy: 0.7348
# Epoch 12/100
# 858/858 [==============================] - 1s 964us/step - loss: 0.5433 - accuracy: 0.7353
# Epoch 13/100
# 858/858 [==============================] - 1s 998us/step - loss: 0.5432 - accuracy: 0.7352
# Epoch 14/100
# 858/858 [==============================] - 1s 974us/step - loss: 0.5426 - accuracy: 0.7351
# Epoch 15/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7365
# Epoch 16/100
# 858/858 [==============================] - 1s 991us/step - loss: 0.5415 - accuracy: 0.7367
# Epoch 17/100
# 858/858 [==============================] - 1s 956us/step - loss: 0.5415 - accuracy: 0.7364
# Epoch 18/100
# 858/858 [==============================] - 1s 963us/step - loss: 0.5415 - accuracy: 0.7365
# Epoch 19/100
# 858/858 [==============================] - 1s 980us/step - loss: 0.5408 - accuracy: 0.7367
# Epoch 20/100
# 858/858 [==============================] - 1s 968us/step - loss: 0.5408 - accuracy: 0.7368
# Epoch 21/100
# 858/858 [==============================] - 1s 968us/step - loss: 0.5408 - accuracy: 0.7369
# Epoch 22/100
# 858/858 [==============================] - 1s 973us/step - loss: 0.5403 - accuracy: 0.7373
# Epoch 23/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7375
# Epoch 24/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7376
# Epoch 25/100
# 858/858 [==============================] - 1s 963us/step - loss: 0.5398 - accuracy: 0.7375
# Epoch 26/100
# 858/858 [==============================] - 1s 977us/step - loss: 0.5395 - accuracy: 0.7373
# Epoch 27/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7370
# Epoch 28/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5397 - accuracy: 0.7378
# Epoch 29/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7380
# Epoch 30/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7385
# Epoch 31/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5391 - accuracy: 0.7383
# Epoch 32/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7378
# Epoch 33/100
# 858/858 [==============================] - 1s 991us/step - loss: 0.5386 - accuracy: 0.7389
# Epoch 34/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7384
# Epoch 35/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7381
# Epoch 36/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7381
# Epoch 37/100
# 858/858 [==============================] - 1s 981us/step - loss: 0.5384 - accuracy: 0.7388
# Epoch 38/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7391
# Epoch 39/100
# 858/858 [==============================] - 1s 955us/step - loss: 0.5380 - accuracy: 0.7386
# Epoch 40/100
# 858/858 [==============================] - 1s 969us/step - loss: 0.5380 - accuracy: 0.7385
# Epoch 41/100
# 858/858 [==============================] - 1s 997us/step - loss: 0.5380 - accuracy: 0.7387
# Epoch 42/100
# 858/858 [==============================] - 1s 972us/step - loss: 0.5376 - accuracy: 0.7379
# Epoch 43/100
# 858/858 [==============================] - 1s 979us/step - loss: 0.5378 - accuracy: 0.7383
# Epoch 44/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5376 - accuracy: 0.7391
# Epoch 45/100
# 858/858 [==============================] - 1s 972us/step - loss: 0.5374 - accuracy: 0.7392
# Epoch 46/100
# 858/858 [==============================] - 1s 991us/step - loss: 0.5376 - accuracy: 0.7388
# Epoch 47/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7392
# Epoch 48/100
# 858/858 [==============================] - 1s 961us/step - loss: 0.5372 - accuracy: 0.7385
# Epoch 49/100
# 858/858 [==============================] - 1s 941us/step - loss: 0.5370 - accuracy: 0.7392
# Epoch 50/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7391
# Epoch 51/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7391
# Epoch 52/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7396
# Epoch 53/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5371 - accuracy: 0.7389
# Epoch 54/100
# 858/858 [==============================] - 1s 955us/step - loss: 0.5369 - accuracy: 0.7395
# Epoch 55/100
# 858/858 [==============================] - 1s 948us/step - loss: 0.5369 - accuracy: 0.7394
# Epoch 56/100
# 858/858 [==============================] - 1s 979us/step - loss: 0.5367 - accuracy: 0.7392
# Epoch 57/100
# 858/858 [==============================] - 1s 934us/step - loss: 0.5365 - accuracy: 0.7397
# Epoch 58/100
# 858/858 [==============================] - 1s 946us/step - loss: 0.5364 - accuracy: 0.7388
# Epoch 59/100
# 858/858 [==============================] - 1s 978us/step - loss: 0.5368 - accuracy: 0.7391
# Epoch 60/100
# 858/858 [==============================] - 1s 973us/step - loss: 0.5363 - accuracy: 0.7392
# Epoch 61/100
# 858/858 [==============================] - 1s 956us/step - loss: 0.5364 - accuracy: 0.7387
# Epoch 62/100
# 858/858 [==============================] - 1s 982us/step - loss: 0.5360 - accuracy: 0.7395
# Epoch 63/100
# 858/858 [==============================] - 1s 944us/step - loss: 0.5366 - accuracy: 0.7382
# Epoch 64/100
# 858/858 [==============================] - 1s 935us/step - loss: 0.5361 - accuracy: 0.7388
# Epoch 65/100
# 858/858 [==============================] - 1s 975us/step - loss: 0.5354 - accuracy: 0.7404
# Epoch 66/100
# 858/858 [==============================] - 1s 974us/step - loss: 0.5361 - accuracy: 0.7398
# Epoch 67/100
# 858/858 [==============================] - 1s 997us/step - loss: 0.5361 - accuracy: 0.7395
# Epoch 68/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 69/100
# 858/858 [==============================] - 1s 984us/step - loss: 0.5354 - accuracy: 0.7392
# Epoch 70/100
# 858/858 [==============================] - 1s 985us/step - loss: 0.5364 - accuracy: 0.7397
# Epoch 71/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7401
# Epoch 72/100
# 858/858 [==============================] - 1s 956us/step - loss: 0.5359 - accuracy: 0.7399
# Epoch 73/100
# 858/858 [==============================] - 1s 980us/step - loss: 0.5356 - accuracy: 0.7405
# Epoch 74/100
# 858/858 [==============================] - 1s 956us/step - loss: 0.5359 - accuracy: 0.7399
# Epoch 75/100
# 858/858 [==============================] - 1s 983us/step - loss: 0.5356 - accuracy: 0.7398
# Epoch 76/100
# 858/858 [==============================] - 1s 969us/step - loss: 0.5355 - accuracy: 0.7406
# Epoch 77/100
# 858/858 [==============================] - 1s 993us/step - loss: 0.5350 - accuracy: 0.7401
# Epoch 78/100
# 858/858 [==============================] - 1s 975us/step - loss: 0.5353 - accuracy: 0.7403
# Epoch 79/100
# 858/858 [==============================] - 1s 945us/step - loss: 0.5357 - accuracy: 0.7390
# Epoch 80/100
# 858/858 [==============================] - 1s 932us/step - loss: 0.5355 - accuracy: 0.7399
# Epoch 81/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7408
# Epoch 82/100
# 858/858 [==============================] - 1s 952us/step - loss: 0.5352 - accuracy: 0.7405
# Epoch 83/100
# 858/858 [==============================] - 1s 996us/step - loss: 0.5352 - accuracy: 0.7405
# Epoch 84/100
# 858/858 [==============================] - 1s 957us/step - loss: 0.5353 - accuracy: 0.7394
# Epoch 85/100
# 858/858 [==============================] - 1s 951us/step - loss: 0.5350 - accuracy: 0.7403
# Epoch 86/100
# 858/858 [==============================] - 1s 991us/step - loss: 0.5351 - accuracy: 0.7405
# Epoch 87/100
# 858/858 [==============================] - 1s 936us/step - loss: 0.5353 - accuracy: 0.7401
# Epoch 88/100
# 858/858 [==============================] - 1s 958us/step - loss: 0.5348 - accuracy: 0.7405
# Epoch 89/100
# 858/858 [==============================] - 1s 967us/step - loss: 0.5351 - accuracy: 0.7402
# Epoch 90/100
# 858/858 [==============================] - 1s 950us/step - loss: 0.5350 - accuracy: 0.7399
# Epoch 91/100
# 858/858 [==============================] - 1s 950us/step - loss: 0.5348 - accuracy: 0.7405
# Epoch 92/100
# 858/858 [==============================] - 1s 990us/step - loss: 0.5344 - accuracy: 0.7409
# Epoch 93/100
# 858/858 [==============================] - 1s 936us/step - loss: 0.5346 - accuracy: 0.7402
# Epoch 94/100
# 858/858 [==============================] - 1s 944us/step - loss: 0.5346 - accuracy: 0.7406
# Epoch 95/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7403
# Epoch 96/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7413
# Epoch 97/100
# 858/858 [==============================] - 1s 1000us/step - loss: 0.5345 - accuracy: 0.7420
# Epoch 98/100
# 858/858 [==============================] - 1s 985us/step - loss: 0.5344 - accuracy: 0.7399
# Epoch 99/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7417
# Epoch 100/100
# 858/858 [==============================] - 1s 983us/step - loss: 0.5345 - accuracy: 0.7412

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - loss: 0.5580 - accuracy: 0.7235 - 156ms/epoch - 728us/step
# Loss: 0.5580423474311829, Accuracy: 0.7234693765640259

# %% [markdown]
# # Attempt 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(x_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 60

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(hidden_nodes_layer1, input_dim= input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 80)                9360
#
#  dense_22 (Dense)            (None, 60)                4860
#
#  dense_23 (Dense)            (None, 1)                 61
#
# =================================================================
# Total params: 14,281
# Trainable params: 14,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(x_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 2s 1ms/step - loss: 0.5747 - accuracy: 0.7239
# Epoch 2/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5540 - accuracy: 0.7312
# Epoch 3/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5503 - accuracy: 0.7318
# Epoch 4/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5482 - accuracy: 0.7329
# Epoch 5/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5447 - accuracy: 0.7353
# Epoch 6/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5453 - accuracy: 0.7346
# Epoch 7/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5442 - accuracy: 0.7349
# Epoch 8/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7363
# Epoch 9/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5423 - accuracy: 0.7371
# Epoch 10/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5414 - accuracy: 0.7359
# Epoch 11/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7374
# Epoch 12/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7369
# Epoch 13/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5402 - accuracy: 0.7372
# Epoch 14/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7378
# Epoch 15/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7387
# Epoch 16/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5385 - accuracy: 0.7381
# Epoch 17/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7393
# Epoch 18/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7405
# Epoch 19/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7399
# Epoch 20/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7397
# Epoch 21/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7388
# Epoch 22/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7398
# Epoch 23/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7389
# Epoch 24/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7407
# Epoch 25/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7394
# Epoch 26/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5354 - accuracy: 0.7407
# Epoch 27/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7411
# Epoch 28/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7407
# Epoch 29/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7399
# Epoch 30/100
# 858/858 [==============================] - 1s 997us/step - loss: 0.5344 - accuracy: 0.7406
# Epoch 31/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7408
# Epoch 32/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7412
# Epoch 33/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7419
# Epoch 34/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7420
# Epoch 35/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7415
# Epoch 36/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7428
# Epoch 37/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7418
# Epoch 38/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7410
# Epoch 39/100
# 858/858 [==============================] - 1s 988us/step - loss: 0.5324 - accuracy: 0.7420
# Epoch 40/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7418
# Epoch 41/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7423
# Epoch 42/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7422
# Epoch 43/100
# 858/858 [==============================] - 1s 998us/step - loss: 0.5321 - accuracy: 0.7429
# Epoch 44/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7428
# Epoch 45/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7423
# Epoch 46/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7416
# Epoch 47/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7421
# Epoch 48/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5309 - accuracy: 0.7426
# Epoch 49/100
# 858/858 [==============================] - 1s 991us/step - loss: 0.5309 - accuracy: 0.7429
# Epoch 50/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7425
# Epoch 51/100
# 858/858 [==============================] - 1s 984us/step - loss: 0.5305 - accuracy: 0.7423
# Epoch 52/100
# 858/858 [==============================] - 1s 982us/step - loss: 0.5301 - accuracy: 0.7426
# Epoch 53/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7435
# Epoch 54/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7428
# Epoch 55/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.7436
# Epoch 56/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.7431
# Epoch 57/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5300 - accuracy: 0.7432
# Epoch 58/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5300 - accuracy: 0.7426
# Epoch 59/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5295 - accuracy: 0.7428
# Epoch 60/100
# 858/858 [==============================] - 1s 987us/step - loss: 0.5291 - accuracy: 0.7438
# Epoch 61/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5297 - accuracy: 0.7434
# Epoch 62/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5294 - accuracy: 0.7437
# Epoch 63/100
# 858/858 [==============================] - 1s 988us/step - loss: 0.5290 - accuracy: 0.7425
# Epoch 64/100
# 858/858 [==============================] - 1s 982us/step - loss: 0.5291 - accuracy: 0.7441
# Epoch 65/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5290 - accuracy: 0.7426
# Epoch 66/100
# 858/858 [==============================] - 1s 996us/step - loss: 0.5286 - accuracy: 0.7429
# Epoch 67/100
# 858/858 [==============================] - 1s 988us/step - loss: 0.5290 - accuracy: 0.7436
# Epoch 68/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5286 - accuracy: 0.7436
# Epoch 69/100
# 858/858 [==============================] - 1s 981us/step - loss: 0.5293 - accuracy: 0.7430
# Epoch 70/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5289 - accuracy: 0.7434
# Epoch 71/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5291 - accuracy: 0.7436
# Epoch 72/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5286 - accuracy: 0.7432
# Epoch 73/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5287 - accuracy: 0.7435
# Epoch 74/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5291 - accuracy: 0.7430
# Epoch 75/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5280 - accuracy: 0.7435
# Epoch 76/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5283 - accuracy: 0.7444
# Epoch 77/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7433
# Epoch 78/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7433
# Epoch 79/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7432
# Epoch 80/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7436
# Epoch 81/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5279 - accuracy: 0.7439
# Epoch 82/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5276 - accuracy: 0.7439
# Epoch 83/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7435
# Epoch 84/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7431
# Epoch 85/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7443
# Epoch 86/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7435
# Epoch 87/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5293 - accuracy: 0.7435
# Epoch 88/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5278 - accuracy: 0.7439
# Epoch 89/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5274 - accuracy: 0.7437
# Epoch 90/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5274 - accuracy: 0.7444
# Epoch 91/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5273 - accuracy: 0.7436
# Epoch 92/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5271 - accuracy: 0.7443
# Epoch 93/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7440
# Epoch 94/100
# 858/858 [==============================] - 1s 998us/step - loss: 0.5271 - accuracy: 0.7441
# Epoch 95/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7434
# Epoch 96/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5277 - accuracy: 0.7442
# Epoch 97/100
# 858/858 [==============================] - 1s 987us/step - loss: 0.5277 - accuracy: 0.7441
# Epoch 98/100
# 858/858 [==============================] - 1s 984us/step - loss: 0.5270 - accuracy: 0.7443
# Epoch 99/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5267 - accuracy: 0.7436
# Epoch 100/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5270 - accuracy: 0.7436

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - loss: 0.5990 - accuracy: 0.7251 - 219ms/epoch - 1ms/step
# Loss: 0.5989859104156494, Accuracy: 0.7250728607177734

# %% [markdown]
# # Attempt 3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(x_train_scaled[0])
hidden_nodes_layer1 = 300
hidden_nodes_layer2 = 150

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(hidden_nodes_layer1, input_dim= input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 300)               35100
#
#  dense_28 (Dense)            (None, 150)               45150
#
#  dense_29 (Dense)            (None, 1)                 151
#
# =================================================================
# Total params: 80,401
# Trainable params: 80,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(x_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5761 - accuracy: 0.7238
# Epoch 2/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5531 - accuracy: 0.7322
# Epoch 3/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7322
# Epoch 4/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5468 - accuracy: 0.7344
# Epoch 5/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5459 - accuracy: 0.7341
# Epoch 6/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5444 - accuracy: 0.7337
# Epoch 7/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7352
# Epoch 8/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7363
# Epoch 9/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7347
# Epoch 10/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5422 - accuracy: 0.7371
# Epoch 11/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5411 - accuracy: 0.7369
# Epoch 12/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7369
# Epoch 13/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7380
# Epoch 14/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7391
# Epoch 15/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7377
# Epoch 16/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7384
# Epoch 17/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7381
# Epoch 18/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7390
# Epoch 19/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7402
# Epoch 20/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7386
# Epoch 21/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7399
# Epoch 22/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7396
# Epoch 23/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7397
# Epoch 24/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7400
# Epoch 25/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7394
# Epoch 26/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7402
# Epoch 27/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5357 - accuracy: 0.7408
# Epoch 28/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5350 - accuracy: 0.7411
# Epoch 29/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7412
# Epoch 30/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5357 - accuracy: 0.7413
# Epoch 31/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5347 - accuracy: 0.7410
# Epoch 32/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5339 - accuracy: 0.7418
# Epoch 33/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5355 - accuracy: 0.7414
# Epoch 34/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5338 - accuracy: 0.7415
# Epoch 35/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5336 - accuracy: 0.7403
# Epoch 36/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7414
# Epoch 37/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7419
# Epoch 38/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7412
# Epoch 39/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7413
# Epoch 40/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7411
# Epoch 41/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7409
# Epoch 42/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7414
# Epoch 43/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7418
# Epoch 44/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7419
# Epoch 45/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7419
# Epoch 46/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5320 - accuracy: 0.7422
# Epoch 47/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5330 - accuracy: 0.7420
# Epoch 48/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5350 - accuracy: 0.7419
# Epoch 49/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5311 - accuracy: 0.7419
# Epoch 50/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5313 - accuracy: 0.7423
# Epoch 51/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7421
# Epoch 52/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7421
# Epoch 53/100
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5312 - accuracy: 0.7422
# Epoch 54/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7430
# Epoch 55/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7420
# Epoch 56/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7420
# Epoch 57/100
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5306 - accuracy: 0.7420
# Epoch 58/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5302 - accuracy: 0.7431
# Epoch 59/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5302 - accuracy: 0.7427
# Epoch 60/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5299 - accuracy: 0.7421
# Epoch 61/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5303 - accuracy: 0.7429
# Epoch 62/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5298 - accuracy: 0.7422
# Epoch 63/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5303 - accuracy: 0.7424
# Epoch 64/100
# 858/858 [==============================] - 4s 4ms/step - loss: 0.5302 - accuracy: 0.7427
# Epoch 65/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5298 - accuracy: 0.7428
# Epoch 66/100
# 858/858 [==============================] - 4s 5ms/step - loss: 0.5300 - accuracy: 0.7429
# Epoch 67/100
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5305 - accuracy: 0.7432
# Epoch 68/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5297 - accuracy: 0.7428
# Epoch 69/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5297 - accuracy: 0.7429
# Epoch 70/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5449 - accuracy: 0.7432
# Epoch 71/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5299 - accuracy: 0.7427
# Epoch 72/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5289 - accuracy: 0.7435
# Epoch 73/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5286 - accuracy: 0.7425
# Epoch 74/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5294 - accuracy: 0.7429
# Epoch 75/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5299 - accuracy: 0.7435
# Epoch 76/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7427
# Epoch 77/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5294 - accuracy: 0.7430
# Epoch 78/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5469 - accuracy: 0.7425
# Epoch 79/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5291 - accuracy: 0.7430
# Epoch 80/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5293 - accuracy: 0.7430
# Epoch 81/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7435
# Epoch 82/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7433
# Epoch 83/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7434
# Epoch 84/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5291 - accuracy: 0.7432
# Epoch 85/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5279 - accuracy: 0.7428
# Epoch 86/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7429
# Epoch 87/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7432
# Epoch 88/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5286 - accuracy: 0.7426
# Epoch 89/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5290 - accuracy: 0.7432
# Epoch 90/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5280 - accuracy: 0.7438
# Epoch 91/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7430
# Epoch 92/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5288 - accuracy: 0.7432
# Epoch 93/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7436
# Epoch 94/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5745 - accuracy: 0.7436
# Epoch 95/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5288 - accuracy: 0.7436
# Epoch 96/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7432
# Epoch 97/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5280 - accuracy: 0.7437
# Epoch 98/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5275 - accuracy: 0.7438
# Epoch 99/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5275 - accuracy: 0.7432
# Epoch 100/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5281 - accuracy: 0.7437

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(x_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - loss: 0.6110 - accuracy: 0.7270 - 196ms/epoch - 911us/step
# Loss: 0.6110023260116577, Accuracy: 0.7269679307937622

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization.h5")
